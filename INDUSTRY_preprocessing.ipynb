# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

# %%
# !pip install openpyxl --upgrade

# %%
df = pd.read_excel('/content/drive/MyDrive/INDUSTRY(DUMMY)_python.xlsx')
df
# Out:
#               Ticker  ...                              Unnamed: 2
# 0     KOSDAQ:A000250  ...                         Pharmaceuticals
# 1     KOSDAQ:A000440  ...  Oil and Gas Storage and Transportation
# 2     KOSDAQ:A001000  ...                                Textiles
# 3     KOSDAQ:A001540  ...                         Pharmaceuticals
# 4     KOSDAQ:A001810  ...                          Paper Products
# ...              ...  ...                                     ...
# 2295    KOSE:A381970  ...                       Automotive Retail
# 2296    KOSE:A383220  ...   Apparel, Accessories and Luxury Goods
# 2297    KOSE:A383800  ...                Industrial Conglomerates
# 2298    KOSE:A402340  ...                          Semiconductors
# 2299    KOSE:A900140  ...                       Automotive Retail
#
# [2300 rows x 3 columns]

# %%
financial_list = ['Asset Management and Custody Banks', 'Investment Banking and Brokerage', 'Regional Banks', 'Diversified Banks', 'Property and Casualty Insurance', 'Reinsurance', 'Life and Health Insurance', 'Insurance Brokers', 'Specialized Finance', 'Consumer Finance', 'Thrifts and Mortgage Finance', 'Other Diversified Financial Services']
drop_list = []
for i in financial_list:
  drop_list = drop_list + list(df['Ticker'][df.iloc[:, 2] == i].values)
drop_list.sort()

# %%
pd.DataFrame(drop_list).to_excel(('/content/drive/MyDrive/financial_list.xlsx'))

# %%
not_drop_list = []
for i in list(df['Ticker']):
 if i not in drop_list:
   not_drop_list.append(i)
len(not_drop_list)
# Out:
# 2186

# %%
pd.DataFrame(not_drop_list).to_excel(('/content/drive/MyDrive/not_financial_list.xlsx'))
